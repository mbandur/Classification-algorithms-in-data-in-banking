# %% [markdown]
# # Final overview and comparison of all models results

# %% [markdown]
# ### Legend:
#     - LR  - LogisticRegression
#     - TDC - DecisionTreeClassifier
#     - RFC - RandomForestClassifier
#     - SVM - SVC
#     - KNC - KNeighborsClassifier
#     - XGB - XGBClassifier
#
#     - wds - models with default settings
#     - wcw - models with class weights
#     - wgs - models with grid search optimization
#
#     - 1 - scores for class 1
#     - ALL - weighted avg scores

# %% [markdown]
# ### Importing necessary libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')
import functions

# %% [markdown]
# ## Overview the models results

# %% [markdown]
# ##### Results for models with default settings:

# %%
results_wds = pd.read_csv(r'./results/results_wds.csv', delimiter = ';', index_col='Model')
results_wds.plot.barh(figsize=(15,10), width=0.9)
plt.xticks(np.arange(0, 1, step = 0.05))
plt.show()
results_wds
# Out:
#                              ACC       AUC  PRECISION_ALL  RECALL_ALL  \
# Model
# LogisticRegression      0.900923  0.228876       0.883316    0.900923
# DecisionTreeClassifier  0.844949  0.232588       0.846184    0.844949
# RandomForestClassifier  0.891452  0.253951       0.871517    0.891452
# SVC                     0.898494  0.207324       0.878919    0.898494
# KNeighborsClassifier    0.891695  0.246699       0.871159    0.891695
# XGBClassifier           0.902258  0.232263       0.885846    0.902258
#
#                           F1_ALL  PRECISION_1  RECALL_1      F1_1       MAE
# Model
# LogisticRegression      0.879974     0.663743  0.244612  0.357480  0.099077
# DecisionTreeClassifier  0.845562     0.315344  0.321121  0.318206  0.155051
# RandomForestClassifier  0.876545     0.534274  0.285560  0.372191  0.108548
# SVC                     0.875910     0.642857  0.223060  0.331200  0.101506
# KNeighborsClassifier    0.875981     0.537657  0.276940  0.365576  0.108305
# XGBClassifier           0.881218     0.683582  0.246767  0.362629  0.097742

# %% [markdown]
# ##### Results for models with class weights:

# %%
results_wcw = pd.read_csv(r'./results/results_wcw.csv', delimiter = ';', index_col='Model')
results_wcw.plot.barh(figsize=(15,10), width=0.9)
plt.xticks(np.arange(0, 1, step = 0.05))
plt.show()                      
results_wcw
# Out:
#                              ACC       AUC  PRECISION_ALL  RECALL_ALL  \
# Model
# LogisticRegression      0.831472  0.467638       0.878758    0.831472
# DecisionTreeClassifier  0.840578  0.235187       0.845665    0.840578
# RandomForestClassifier  0.880767  0.328459       0.871856    0.880767
# SVC                     0.849199  0.460335       0.879987    0.849199
# KNeighborsClassifier    0.763963  0.335112       0.854817    0.763963
# XGBClassifier           0.833536  0.474668       0.880010    0.833536
#
#                           F1_ALL  PRECISION_1  RECALL_1      F1_1       MAE
# Model
# LogisticRegression      0.849591     0.355164  0.607759  0.448331  0.168528
# DecisionTreeClassifier  0.843057     0.306921  0.329741  0.317922  0.159422
# RandomForestClassifier  0.875789     0.464844  0.384698  0.420991  0.119233
# SVC                     0.861642     0.386561  0.576509  0.462803  0.150801
# KNeighborsClassifier    0.798213     0.249012  0.543103  0.341463  0.236037
# XGBClassifier           0.851305     0.359899  0.613147  0.453567  0.166464

# %% [markdown]
# ##### Results for models with grid search optimization:

# %%
results_wgs = pd.read_csv(r'./results/results_wgs.csv', delimiter = ';', index_col='Model')
results_wgs.plot.barh(figsize=(15,10), width=0.9)
plt.xticks(np.arange(0, 1, step = 0.05))
plt.show()
results_wgs
# Out:
#                              ACC       AUC  PRECISION_ALL  RECALL_ALL  \
# Model
# LogisticRegression      0.831107  0.469109       0.878940    0.831107
# DecisionTreeClassifier  0.802817  0.336566       0.856523    0.802817
# RandomForestClassifier  0.845313  0.479475       0.882133    0.845313
# SVC                     0.847863  0.466355       0.880631    0.847863
# KNeighborsClassifier    0.849563  0.223676       0.845912    0.849563
# XGBClassifier           0.833779  0.485290       0.881604    0.833779
#
#                           F1_ALL  PRECISION_1  RECALL_1      F1_1       MAE
# Model
# LogisticRegression      0.849394     0.354859  0.609914  0.448672  0.168893
# DecisionTreeClassifier  0.824568     0.284387  0.494612  0.361133  0.197183
# RandomForestClassifier  0.859739     0.381992  0.603448  0.467836  0.154687
# SVC                     0.860971     0.384833  0.585129  0.464301  0.152137
# KNeighborsClassifier    0.847699     0.322691  0.304957  0.313573  0.150437
# XGBClassifier           0.851884     0.362274  0.625000  0.458679  0.166221

# %% [markdown]
# ## The highest scores achived for models

# %% [markdown]
# #### Models with default settings:

# %%
functions.max_scores(results_wds)
# Out:
#            score                   model     value
# 0            ACC           XGBClassifier  0.902258
# 1            AUC  RandomForestClassifier  0.253951
# 2  PRECISION_ALL           XGBClassifier  0.885846
# 3     RECALL_ALL           XGBClassifier  0.902258
# 4         F1_ALL           XGBClassifier  0.881218
# 5    PRECISION_1           XGBClassifier  0.683582
# 6       RECALL_1  DecisionTreeClassifier  0.321121
# 7           F1_1  RandomForestClassifier  0.372191

# %% [markdown]
# #### Models with class weights:

# %%
functions.max_scores(results_wcw)
# Out:
#            score                   model     value
# 0            ACC  RandomForestClassifier  0.880767
# 1            AUC           XGBClassifier  0.474668
# 2  PRECISION_ALL           XGBClassifier  0.880010
# 3     RECALL_ALL  RandomForestClassifier  0.880767
# 4         F1_ALL  RandomForestClassifier  0.875789
# 5    PRECISION_1  RandomForestClassifier  0.464844
# 6       RECALL_1           XGBClassifier  0.613147
# 7           F1_1                     SVC  0.462803

# %% [markdown]
# #### Models with grid search optimization:

# %%
functions.max_scores(results_wgs)
# Out:
#            score                   model     value
# 0            ACC    KNeighborsClassifier  0.849563
# 1            AUC           XGBClassifier  0.485290
# 2  PRECISION_ALL  RandomForestClassifier  0.882133
# 3     RECALL_ALL    KNeighborsClassifier  0.849563
# 4         F1_ALL                     SVC  0.860971
# 5    PRECISION_1                     SVC  0.384833
# 6       RECALL_1           XGBClassifier  0.625000
# 7           F1_1  RandomForestClassifier  0.467836

# %% [markdown]
# ## Comparison of the models results

# %% [markdown]
# ### Models with default settings and models with grid search optimization - comparison

# %% [markdown]
# Models with default settings:
# - All models have the highest: ACC, recall (weighted avg), F1 (weighted avg), precision (class: 1) scores
# - 2 models (RFC and SVC) have the highest precision (weighted avg) scores
#
# Models with class weights:
# - All models have the the highest: AUC and recall (class: 1) scores
# - 4 models (without DTC and KNC) have the highest F1 (class: 1) scores

# %% [markdown]
# ##### The highest scores achieved for models:

# %%
results_wds_wcw = pd.read_csv(r'./results/results_wds_wcw.csv', delimiter = ';', index_col='the highest score')
results_wds_wcw
# Out:
#                       value    model the lowest scores   value.1  model.1
# the highest score
# ACC                 0,9023   XGB wcw               ACC   0,7640   KNC wgs
# AUC                 0,4747   XGB wgs               AUC   0,2073   SVC wcw
# PRECISION_ALL       0,8858   XGB wcw     PRECISION_ALL   0,8457   DTC wgs
# RECALL_ALL          0,9023   XGB wcw        RECALL_ALL   0,7640   KNC wgs
# F1_ALL              0,8812   XGB wcw            F1_ALL   0,7982   KNC wgs
# PRECISION_1         0,6836   XGB wcw       PRECISION_1   0,2490   KNC wgs
# RECALL_1            0,6131   XGB wgs          RECALL_1   0,2231   SVC wcw
# F1_1                0,4628   SVC wgs              F1_1   0,3179   DTC wgs

# %% [markdown]
# ### Models with class weights and models with grid search optimization - comparison

# %% [markdown]
# Models with class weights:
# - 4 models (without KNC and XGB) have the highest: ACC, recall (weighted avg), F1 (weighted avg) and precision (class: 1) scores
#
# Models with grid search optimization:
# - 5 models (without KNC) have the highest: AUC, precision (weighted avg), recall (class: 1) scores

# %% [markdown]
# ##### The highest scores achieved for models:

# %%
results_wcw_wgs = pd.read_csv(r'./results/results_wcw_wgs.csv', delimiter = ';', index_col='the highest score')
results_wcw_wgs
# Out:
#                     value    model the lowest scores value.1  model.1
# the highest score
# ACC                0,8808  RFC wcw               ACC   0,764  KNC wcw
# AUC                0,4853  XGB wgs               AUC  0,2237  KNC wgs
# PRECISION_ALL      0,8821  RFC wgs     PRECISION_ALL  0,8457  DTC wcw
# RECALL_ALL         0,8808  RFC wcw        RECALL_ALL   0,764  KNC wcw
# F1_ALL             0,8758  RFC wcw            F1_ALL  0,7982  KNC wcw
# PRECISION_1        0,4648  RFC wcw       PRECISION_1   0,249  KNC wcw
# RECALL_1            0,625  XGB wgs          RECALL_1   0,305  KNC wgs
# F1_1               0,4678  RFC wgs              F1_1  0,3136  KNC wgs
